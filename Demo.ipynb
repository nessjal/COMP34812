# %%
from google.colab import drive
drive.mount('/content/drive')

path = "/content/drive/MyDrive/Colab Notebooks/"
# Out:
# Mounted at /content/drive

# %%
# import libraries here
import pandas as pd
from transformers import BertTokenizer, BertForSequenceClassification
import torch
from torch.utils.data import Dataset, DataLoader
from peft import LoraConfig, get_peft_model, TaskType

from transformers import logging
logging.set_verbosity_error()
import warnings
warnings.filterwarnings('ignore', category=UserWarning, module='huggingface_hub.utils._auth')

# %% [markdown]
# # Import data

# %%
# import data
test = pd.read_csv(path + 'test.csv')

# %%
# show head
test.head()
# Out:
#                                          Claim  \
# 0  We should further exploit geothermal energy
# 1       We should prohibit corporal punishment
# 2       We should ban male infant circumcision
# 3       We should ban trans fats usage in food
# 4                         We should ban boxing
#
#                                             Evidence
# 0  Taxpayer funding of research and development o...
# 1  Regarding discipline, Sukhmani writes that cor...
# 2  Benatar and Benatar (2003) argue that "it is f...
# 3  Each KIND bar is gluten free, dairy free, non ...
# 4  About Feng Keshan and Meihuaquan: In the 1800s...

# %% [markdown]
# # Load Model

# %%
hp = {
    'use_lora': True,
    'maxlen': 128,
    'batchsize':8,
}

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
# initialize model
model = BertForSequenceClassification.from_pretrained('bert-base-uncased', num_labels=2)
if hp['use_lora']:
  lora_config = LoraConfig(r=16, lora_alpha=32, target_modules=["query", "value"], lora_dropout=0.05, bias="none", task_type=TaskType.SEQ_CLS, inference_mode=True)
  model = get_peft_model(model, lora_config)

# load model weights
model.load_state_dict(torch.load(path + 'model.pt'))

model.to(device)
print(f'Model loaded to {device}')
# Out:
# Model loaded to cuda

# %% [markdown]
# # Preprocessing

# %%
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
encodings = tokenizer(test['Claim'].tolist(), test['Evidence'].tolist(), return_tensors='pt', padding=True, truncation=True, max_length=hp['maxlen'])

# %%
class InputDataset(Dataset):
    def __init__(self, encodings):
        self.encodings = encodings

    def __len__(self):
        return len(self.encodings["input_ids"])

    def __getitem__(self, idx):
        return {
            "input_ids": self.encodings["input_ids"][idx],
            "token_type_ids": self.encodings["token_type_ids"][idx],
            "attention_mask": self.encodings["attention_mask"][idx],
        }

# %%
# convert to dataset and create dataloader
dataset = InputDataset(encodings)
dataloader = DataLoader(dataset, batch_size=hp['batchsize'], shuffle=False)

# %% [markdown]
# # Predict

# %%
model.eval()
predictions = []

with torch.no_grad():
    for batch in dataloader:
        # move inputs to device
        input_ids = batch['input_ids'].to(device)
        attention_mask = batch['attention_mask'].to(device)

        # forward pass
        outputs = model(input_ids, attention_mask=attention_mask)
        logits = outputs.logits

        # get predicted class
        pred = torch.argmax(logits, dim=1)

        # store prediction
        predictions.extend(pred.cpu().tolist())

# %%
# save predictions
df = pd.DataFrame({'prediction': predictions})
df.to_csv(path + 'predictions.csv', index=False)
